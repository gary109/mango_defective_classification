# %%
import os

# %%
NET_SIZE = 64 #128
NORM='batch'
# NORM='instance'
# EPOCH = '100'
EPOCH = 'latest'#100#'latest'

# %%
NEF='%d'%(NET_SIZE)
NGF='%d'%(NET_SIZE)
NDF='%d'%(NET_SIZE)
G_MODEL_NAME = '%s_net_G.pth'%(EPOCH)
D_MODEL_NAME = '%s_net_D.pth'%(EPOCH)

# %%
CMD='./predict_pitch.py' 
MODEL='pix2pix'
CLASS='singing_transcription'
DIRECTION='AtoB' # from domain A to domain B
LOAD_SIZE=256 # scale images to this size
CROP_SIZE=256 # then crop to this size
INPUT_NC=3  # number of channels in the input image
NO_FLIP='--no_flip'

# DATAROOT='../../BicycleGAN/datasets/datasets/Singing_transcription'
# DATAROOT='./datasets/original/AIcup_testset_ok/1'    # 徐若瑄Vivian《別人的 Yours Always》正式婚紗版 MV（《孤味》電影片尾曲）
# DATAROOT='./datasets/original/AIcup_testset_ok/495'  # 張韶涵 Angela Zhang - 隱形的翅膀 (官方版MV)
# DATAROOT='./datasets/original/AIcup_testset_ok/1024' # 李千那-查某囡仔 Official Music Video
# DATAROOT='./datasets/original/AIcup_testset_ok/1256' # 五月天 Mayday【倔強 Stubborn】Official Music Video
# DATAROOT='./datasets/original/AIcup_testset_ok/1235' # Jay Chou 周杰倫【給我一首歌的時間 Give me the time of a song】
# DATAROOT='./datasets/original/AIcup_testset_ok/1151' # 脫拉庫 TOLAKU - 我愛夏天
# DATAROOT='./datasets/original/AIcup_testset_ok/1046' # 孫燕姿 Sun Yan-Zi - 綠光 Green Light (official 官方完整版MV)
# DATAROOT='./datasets/original/AIcup_testset_ok/1344' # The Turtles - Happy Together (Lyric Video)
# DATAROOT='./datasets/original/AIcup_testset_ok/156'  # 曾沛慈 Pets Tseng《大風吹Miss You》Official Music Video
DATAROOT='./datasets/original/AIcup_testset_ok/1216' # 梅豔芳 女人花 
# DATAROOT='./datasets/original/AIcup_testset_ok/1174'   # Ed Sheeran - Castle On The Hill [Official Lyric Video]
# DATAROOT='./datasets/original/AIcup_testset_ok/1178'   # 五月天 Mayday【知足 Contentment】Official Music Video
# DATAROOT='./datasets/original/AIcup_testset_ok/1181'   # 任賢齊 Richie Jen&阿牛(陳慶祥) Aniu (Tan Kheng Seong)【再出發 Set out again】Official Music Video
# DATAROOT='./datasets/original/AIcup_testset_ok/1186' # 魏如萱 waa wei [ 你啊你啊 Only You ] Official Music Video
# DATAROOT='./datasets/original/AIcup_testset_ok/1189' # Jay Chou 周杰倫【最長的電影 The Longest Movie】-Official Music Video
# DATAROOT='./datasets/original/AIcup_testset_ok/1197' # Adele - Rolling in the Deep (Official Music Video)
# DATAROOT='./datasets/original/AIcup_testset_ok/1204' # Richard Marx - Right Here Waiting (Official Video) 理查·馬克斯
# DATAROOT='./datasets/original/AIcup_testset_ok/1205' # BEYOND【海闊天空】Music Video
# DATAROOT='./datasets/original/AIcup_testset_ok/1207' # Christina Perri - A Thousand Years [Official Music Video]
# DATAROOT='./datasets/original/AIcup_testset_ok/1209' # G.E.M.【再見 GOODBYE】Official MV [HD] 鄧紫棋
# DATAROOT='./datasets/original/AIcup_testset_ok/1215'   # 林憶蓮 Sandy Lam - 至少還有你 At Least I've Got You (官方完整版MV)
# DATAROOT='./datasets/original/AIcup_testset_ok/1225' # 周杰倫 Jay Chou【聽爸爸的話 Listen to Dad】Official MV
# DATAROOT='./datasets/original/AIcup_testset_ok/1226' # Jay Chou周杰倫【晴天 Sunny Day】-Official Music Video
# DATAROOT='./datasets/original/AIcup_testset_ok/1231' # 李千娜 Nana Lee – 心花開 (Official Music Video)
# DATAROOT='./datasets/original/AIcup_testset_ok/10000' # Dance Monkey
# DATAROOT='./datasets/original/AIcup_testset_ok/304' #甄妮 魯冰花（TVB原版MV） Jenny & Melody
# DATAROOT='./datasets/original/AIcup_testset_ok/426' #劉若英 René Liu【很愛很愛你 Love you so much】Official Music Video
# DATAROOT='./datasets/original/AIcup_testset_ok/1001' #周杰倫 Jay Chou【開不了口 I Find It Hard To Say】Official MV
# DATAROOT='./datasets/original/AIcup_testset_ok/1005' #Eric周興哲《怎麼了 What's Wrong》Official Music Video - 華劇【你有念大學嗎？】片尾曲
# DATAROOT='./datasets/original/AIcup_testset_ok/1033' #陳奕迅 - 讓我留在你身邊(高音質版)
# DATAROOT='./datasets/original/AIcup_testset_ok/1392' # 羅文-小李飛刀
# DATAROOT='./datasets/original/AIcup_testset_ok/1159' # Ed Sheeran - Shape Of You [Official Lyric Video]
# DATAROOT='./datasets/original/AIcup_testset_ok/1128' # Let It Be (Remastered 2009)
# DATAROOT='./datasets/original/AIcup_testset_ok/1124' # Against All Odds (Take a Look at Me Now)
# DATAROOT='./datasets/original/AIcup_testset_ok/1121' # Imagine Dragons - Believer
# DATAROOT='./datasets/original/AIcup_testset_ok/1116' # 大壯【我們不一樣】HD 高清官方歌詞版 MV
# DATAROOT='./datasets/original/AIcup_testset_ok/1077' # 周杰倫 Jay Chou【不愛我就拉倒 If You Don't Love Me, It's Fine】

CHECKPOINTS_DIR='./pretrained_models/%s/'%(CLASS)
# PHASE='--phase predict'
PHASE='--phase predict_test'
CPU='--gpu_ids -1'
GPU_ID=0   # gpu id
NUM_TEST=1000 # number of input images duirng test
# number of samples per input images
NUM_SAMPLES='--n_samples 1' 
# USE_DROPOUT='--use_dropout'
NAME='%s_%s'%(CLASS,MODEL)
# RESULTS_DIR='./results/%s/'%(NAME)
RESULTS_DIR='./results/'
NET_G='--netG unet_256'
DATASET_MODE='--dataset_mode single'#'aligned'

# %%
os.environ['CMD']=str(CMD)
os.environ['MODEL']=str(MODEL)
os.environ['CLASS']=str(CLASS)
os.environ['DIRECTION']=str(DIRECTION)
os.environ['LOAD_SIZE']=str(LOAD_SIZE)
os.environ['CROP_SIZE']=str(CROP_SIZE)
os.environ['INPUT_NC']=str(INPUT_NC)
os.environ['NO_FLIP']=str(NO_FLIP)
os.environ['DATAROOT']=str(DATAROOT)
os.environ['CHECKPOINTS_DIR']=str(CHECKPOINTS_DIR)
os.environ['PHASE']=str(PHASE)
os.environ['CPU']=str(CPU)
os.environ['GPU_ID']=str(GPU_ID)
os.environ['NUM_TEST']=str(NUM_TEST)
os.environ['NUM_SAMPLES']=str(NUM_SAMPLES)
os.environ['NAME']=str(NAME)
os.environ['RESULTS_DIR']=str(RESULTS_DIR)
os.environ['NET_G']=str(NET_G)
# os.environ['USE_DROPOUT']=str(USE_DROPOUT)
os.environ['DATASET_MODE']=str(DATASET_MODE)
os.environ['G_MODEL_NAME']=str(G_MODEL_NAME)
os.environ['D_MODEL_NAME']=str(D_MODEL_NAME)
os.environ['EPOCH']=str(EPOCH)

os.environ['NEF']=str(NEF)
os.environ['NGF']=str(NGF)
os.environ['NDF']=str(NDF)

# %%
if NET_SIZE == 64 and NORM == 'batch':
    ! cp -rf ../../BicycleGAN/checkpoints/singing_transcription/singing_transcription_pix2pix/$G_MODEL_NAME ./pretrained_models/singing_transcription/singing_transcription_pix2pix/
    ! cp -rf ../../BicycleGAN/checkpoints/singing_transcription/singing_transcription_pix2pix/$D_MODEL_NAME ./pretrained_models/singing_transcription/singing_transcription_pix2pix/
elif NET_SIZE == 64 and NORM == 'instance':
    ! cp -rf ../../BicycleGAN/checkpoints/singing_transcription_64_instance/singing_transcription_64_instance_pix2pix/$G_MODEL_NAME ./pretrained_models/singing_transcription/singing_transcription_pix2pix/
    ! cp -rf ../../BicycleGAN/checkpoints/singing_transcription_64_instance/singing_transcription_64_instance_pix2pix/$D_MODEL_NAME ./pretrained_models/singing_transcription/singing_transcription_pix2pix/
else: #'batch' 128
    ! cp -rf ../../BicycleGAN/checkpoints/singing_transcription_128/singing_transcription_128_pix2pix/$G_MODEL_NAME ./pretrained_models/singing_transcription/singing_transcription_pix2pix/
    ! cp -rf ../../BicycleGAN/checkpoints/singing_transcription_128/singing_transcription_128_pix2pix/$D_MODEL_NAME ./pretrained_models/singing_transcription/singing_transcription_pix2pix/

# %%
#   --dataset_mode single \
#   --suffix 1_ \
#   $USE_DROPOUT \

! CUDA_VISIBLE_DEVICES=$GPU_ID python $CMD \
  --dataroot $DATAROOT \
  --results_dir $RESULTS_DIR \
  --checkpoints_dir $CHECKPOINTS_DIR \
  --name $NAME \
  --model $MODEL \
  --serial_batches \
  $PHASE \
  $DATASET_MODE  \
  --direction $DIRECTION \
  --load_size $LOAD_SIZE \
  --crop_size $CROP_SIZE \
  --input_nc $INPUT_NC \
  --num_test $NUM_TEST \
  $NUM_SAMPLES \
  --center_crop \
  --no_encode \
  --epoch $EPOCH \
  --nef $NEF \
  --ngf $NGF \
  --ndf $NDF \
  --norm $NORM \
  $NO_FLIP \
  $NET_G \
  $CPU
print ('Done')
# Out:
# The /workspace/AIcup/singing_transcription/.ipynb_checkpoints is deleted successfully
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 2
#               center_crop: True                          	[default: False]
#           checkpoints_dir: ./pretrained_models/singing_transcription/	[default: ./checkpoints]
#             conditional_D: False
#                 crop_size: 256
#                  dataroot: ./datasets/original/AIcup_testset_ok/1216	[default: None]
#              dataset_mode: single                        	[default: aligned]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: xavier
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
# ...
