# %%
from utils import Utils
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
# %matplotlib inline

# %%
# ! pip install youtube_dl mido madmom  praat-parselmouth midiutil dominate

# %%
utils = Utils()
utils.init_vars()
utils.init_datasets(output_root = '../../BicycleGAN/datasets/datasets/Singing_transcription')
# Out:
# hop_length=512, sample_rate=None, time_steps=1.024000, shift=1, pixel_interval=0.016000, time_interval=4.096000, isTrain=1, renew_all=1
# The /workspace/AIcup/singing_transcription/.ipynb_checkpoints is deleted successfully

# %%
# song_id = 1    # 徐若瑄Vivian《別人的 Yours Always》正式婚紗版 MV（《孤味》電影片尾曲）
# song_id = 495  # 張韶涵 Angela Zhang - 隱形的翅膀 (官方版MV)
# song_id = 1024 # 李千那-查某囡仔 Official Music Video
# song_id = 1256 # 五月天 Mayday【倔強 Stubborn】Official Music Video
# song_id = 1235 # Jay Chou 周杰倫【給我一首歌的時間 Give me the time of a song】
# song_id = 1151 # 脫拉庫 TOLAKU - 我愛夏天
# song_id = 1046 # 孫燕姿 Sun Yan-Zi - 綠光 Green Light (official 官方完整版MV)
# song_id = 156  # 曾沛慈 Pets Tseng《大風吹Miss You》Official Music Video
# song_id = 1344 # The Turtles - Happy Together (Lyric Video)
# song_id = 1216 # 梅豔芳 女人花
# song_id = 1174 # Ed Sheeran - Castle On The Hill [Official Lyric Video]
# song_id = 1178 # 五月天 Mayday【知足 Contentment】Official Music Video
# song_id = 1181 # 任賢齊 Richie Jen&阿牛(陳慶祥) Aniu (Tan Kheng Seong)【再出發 Set out again】Official Music Video
# song_id = 1186 # 魏如萱 waa wei [ 你啊你啊 Only You ] Official Music Video
# song_id = 1189 # Jay Chou 周杰倫【最長的電影 The Longest Movie】-Official Music Video
# song_id = 1197 # Adele - Rolling in the Deep (Official Music Video)
# song_id = 1204 # Richard Marx - Right Here Waiting (Official Video) 理查·馬克斯
# song_id = 1205 # BEYOND【海闊天空】Music Video
# song_id = 1207 # Christina Perri - A Thousand Years [Official Music Video]
# song_id = 1209 # G.E.M.【再見 GOODBYE】Official MV [HD] 鄧紫棋
# song_id = 1215 # 林憶蓮 Sandy Lam - 至少還有你 At Least I've Got You (官方完整版MV)
# song_id = 1225 # 周杰倫 Jay Chou【聽爸爸的話 Listen to Dad】Official MV
# song_id = 1226 # Jay Chou周杰倫【晴天 Sunny Day】-Official Music Video
# song_id = 1231 # 李千娜 Nana Lee – 心花開 (Official Music Video)
# song_id = 10000 # Dance Monkey
# song_id = 304 #甄妮 魯冰花（TVB原版MV） Jenny & Melody
# song_id = 426 #劉若英 René Liu【很愛很愛你 Love you so much】Official Music Video
# song_id = 1001 #周杰倫 Jay Chou【開不了口 I Find It Hard To Say】Official MV
# song_id = 1005 #Eric周興哲《怎麼了 What's Wrong》Official Music Video - 華劇【你有念大學嗎？】片尾曲
# song_id = 1033 #陳奕迅 - 讓我留在你身邊(高音質版)
# song_id = 1392 # 羅文-小李飛刀
# song_id = 1159 # Ed Sheeran - Shape Of You [Official Lyric Video]
# song_id = 1128 # Let It Be (Remastered 2009)
# song_id = 1124 # Against All Odds (Take a Look at Me Now)
# song_id = 1121 # Imagine Dragons - Believer
# song_id = 1116 # 大壯【我們不一樣】HD 高清官方歌詞版 MV
song_id = 1216

note_list = utils.result2note(song_id=song_id, result_dir='./results/predict_test/images', pitch_freq_th=.5, filter_noise_ms=60, shift_ms=-50)
# Out:
# [MIDI] ./midi/1216.mid Done

# %%
note_list
# Out:
# [[32.832, 33.264, 55],
#  [33.424, 33.536, 58],
#  [33.568, 34.032, 58],
#  [34.048, 34.112, 59],
#  [34.128, 34.208, 60],
#  [34.304, 34.416, 61],
#  [34.48, 35.104, 58],
#  [36.0, 36.288, 53],
#  [36.464, 37.232, 58],
#  [37.248, 37.408, 60],
#  [37.488, 37.6, 61],
#  [37.664, 38.16, 58],
#  [39.232, 39.488, 51],
#  [39.696, 39.968, 54],
#  [39.984, 40.384, 55],
#  [40.464, 40.624, 63],
#  [40.784, 40.864, 62],
#  [40.88, 41.184, 61],
#  [41.2, 41.504, 60],
#  [41.616, 42.64, 55],
#  [42.736, 44.064, 58],
#  [45.6, 45.952, 60],
#  [46.016, 46.8, 63],
#  [46.832, 47.264, 65],
#  [47.344, 48.176, 63],
#  [48.544, 48.72, 60],
#  [48.88, 49.12, 58],
#  [49.232, 49.536, 60],
#  [49.648, 49.92, 55],
#  [49.984, 50.336, 53],
#  [50.464, 50.72, 50],
#  [50.816, 50.96, 49],
#  [50.976, 51.056, 48],
#  [52.208, 52.32, 48],
#  [52.512, 52.768, 51],
#  [52.848, 53.2, 53],
#  [53.36, 53.552, 70],
#  [60.832, 61.168, 54],
#  [61.232, 61.488, 58],
#  [61.68, 63.568, 67],
#  [63.6, 64.32, 65],
# ...
