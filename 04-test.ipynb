# %%
import os

# %%
CMD='./test.py' 
MODEL='pix2pix'
CLASS='singing_transcription'
DIRECTION='AtoB' # from domain A to domain B
LOAD_SIZE=256 # scale images to this size
CROP_SIZE=256 # then crop to this size
INPUT_NC=3  # number of channels in the input image
NO_FLIP='--no_flip'
# DATAROOT='./datasets/original/AIcup_testset_ok/1/features'
DATAROOT='../../BicycleGAN/datasets/datasets/Singing_transcription'
CHECKPOINTS_DIR='./pretrained_models/%s/'%(CLASS)
PHASE='--phase test'
CPU='--gpu_ids -1'
GPU_ID=3   # gpu id
NUM_TEST=100 # number of input images duirng test
# number of samples per input images
NUM_SAMPLES='--n_samples 1' 
# USE_DROPOUT='--use_dropout'
NAME='%s_%s'%(CLASS,MODEL)
# RESULTS_DIR='./results/%s/'%(NAME)
RESULTS_DIR='./results/'
NET_G='--netG unet_256'
DATASET_MODE='--dataset_mode aligned'#'single'

# %%
os.environ['CMD']=str(CMD)
os.environ['MODEL']=str(MODEL)
os.environ['CLASS']=str(CLASS)
os.environ['DIRECTION']=str(DIRECTION)
os.environ['LOAD_SIZE']=str(LOAD_SIZE)
os.environ['CROP_SIZE']=str(CROP_SIZE)
os.environ['INPUT_NC']=str(INPUT_NC)
os.environ['NO_FLIP']=str(NO_FLIP)
os.environ['DATAROOT']=str(DATAROOT)
os.environ['CHECKPOINTS_DIR']=str(CHECKPOINTS_DIR)
os.environ['PHASE']=str(PHASE)
os.environ['CPU']=str(CPU)
os.environ['GPU_ID']=str(GPU_ID)
os.environ['NUM_TEST']=str(NUM_TEST)
os.environ['NUM_SAMPLES']=str(NUM_SAMPLES)
os.environ['NAME']=str(NAME)
os.environ['RESULTS_DIR']=str(RESULTS_DIR)
os.environ['NET_G']=str(NET_G)
os.environ['DATASET_MODE']=str(DATASET_MODE)

# %%
! cp -rf ../../BicycleGAN/checkpoints/singing_transcription/singing_transcription_pix2pix/latest_net_* ./pretrained_models/singing_transcription/singing_transcription_pix2pix/

# %%
#   --dataset_mode single \
#   --suffix 1_ \

! CUDA_VISIBLE_DEVICES=$GPU_ID python $CMD \
  --dataroot $DATAROOT \
  --results_dir $RESULTS_DIR \
  --checkpoints_dir $CHECKPOINTS_DIR \
  --name $NAME \
  --model $MODEL \
  --serial_batches \
  $PHASE \
  $DATASET_MODE  \
  --direction $DIRECTION \
  --load_size $LOAD_SIZE \
  --crop_size $CROP_SIZE \
  --input_nc $INPUT_NC \
  --num_test $NUM_TEST \
  $NUM_SAMPLES \
  --center_crop \
  --no_encode \
  $NO_FLIP \
  $USE_DROPOUT \
  $NET_G \
  $CPU
print ('Done')
# Out:
# OMP: Info #212: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #210: KMP_AFFINITY: Affinity capable, using global cpuid leaf 11 info
# OMP: Info #154: KMP_AFFINITY: Initial OS proc set respected: 0-19
# OMP: Info #156: KMP_AFFINITY: 20 available OS procs
# OMP: Info #157: KMP_AFFINITY: Uniform topology
# OMP: Info #179: KMP_AFFINITY: 1 packages x 10 cores/pkg x 2 threads/core (10 total cores)
# OMP: Info #214: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #171: KMP_AFFINITY: OS proc 4 maps to package 0 core 1 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 10 maps to package 0 core 1 thread 1
# OMP: Info #171: KMP_AFFINITY: OS proc 1 maps to package 0 core 2 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 11 maps to package 0 core 2 thread 1
# OMP: Info #171: KMP_AFFINITY: OS proc 2 maps to package 0 core 4 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 12 maps to package 0 core 4 thread 1
# OMP: Info #171: KMP_AFFINITY: OS proc 3 maps to package 0 core 5 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 13 maps to package 0 core 5 thread 1
# OMP: Info #171: KMP_AFFINITY: OS proc 0 maps to package 0 core 8 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 14 maps to package 0 core 8 thread 1
# OMP: Info #171: KMP_AFFINITY: OS proc 5 maps to package 0 core 9 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 15 maps to package 0 core 9 thread 1
# OMP: Info #171: KMP_AFFINITY: OS proc 6 maps to package 0 core 10 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 16 maps to package 0 core 10 thread 1
# OMP: Info #171: KMP_AFFINITY: OS proc 7 maps to package 0 core 11 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 17 maps to package 0 core 11 thread 1
# OMP: Info #171: KMP_AFFINITY: OS proc 8 maps to package 0 core 12 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 18 maps to package 0 core 12 thread 1
# OMP: Info #171: KMP_AFFINITY: OS proc 9 maps to package 0 core 13 thread 0
# OMP: Info #171: KMP_AFFINITY: OS proc 19 maps to package 0 core 13 thread 1
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 536 thread 0 bound to OS proc set 4
# The /workspace/AIcup/Singing_transcription/.ipynb_checkpoints is deleted successfully
# The /workspace/AIcup/Singing_transcription/datasets/original/AIcup_testset_ok/2/.ipynb_checkpoints is deleted successfully
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 2
#               center_crop: True                          	[default: False]
#           checkpoints_dir: ./pretrained_models/singing_transcription/	[default: ./checkpoints]
#             conditional_D: False
#                 crop_size: 256
#                  dataroot: ../../BicycleGAN/datasets/datasets/Singing_transcription	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: xavier
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_size: 256                           	[default: 286]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: bicycle_gan]
#                 n_samples: 1                             	[default: 5]
#                      name: singing_transcription_pix2pix 	[default: ]
#                       ndf: 64
#                       nef: 64
#                      netD: basic_256_multi
#                     netD2: basic_256_multi
#                      netE: resnet_256
#                      netG: unet_256
#                       ngf: 64
#                        nl: relu
#                 no_encode: True                          	[default: False]
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                    num_Ds: 2
#                  num_test: 100                           	[default: 50]
#               num_threads: 4
#                        nz: 0
#                 output_nc: 3
#                     phase: test                          	[default: val]
#                preprocess: resize_and_crop
#               results_dir: ./results/                    	[default: ../results/]
#            serial_batches: True                          	[default: False]
#                    suffix:
#                      sync: False
#                  upsample: basic
#               use_dropout: False
#                   verbose: False
#                 where_add: input
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with xavier
# model [Pix2PixModel] was created
# loading the model from ./pretrained_models/singing_transcription/singing_transcription_pix2pix/latest_net_G.pth
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 558 thread 1 bound to OS proc set 1
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 559 thread 2 bound to OS proc set 2
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 560 thread 3 bound to OS proc set 3
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 561 thread 4 bound to OS proc set 0
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 562 thread 5 bound to OS proc set 5
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 563 thread 6 bound to OS proc set 6
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 564 thread 7 bound to OS proc set 7
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 565 thread 8 bound to OS proc set 8
# OMP: Info #250: KMP_AFFINITY: pid 536 tid 566 thread 9 bound to OS proc set 9
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.419 M
# -----------------------------------------------
# Loading model pix2pix
# OMP: Info #250: KMP_AFFINITY: pid 567 tid 567 thread 0 bound to OS proc set 4
# process input image(104_810.png) 001/100
# process input image(105_801.png) 002/100
# process input image(110_863.png) 003/100
# process input image(112_1048.png) 004/100
# process input image(115_434.png) 005/100
# process input image(121_492.png) 006/100
# process input image(127_1250.png) 007/100
# process input image(135_221.png) 008/100
# process input image(140_144.png) 009/100
# process input image(143_624.png) 010/100
# process input image(148_409.png) 011/100
# process input image(152_284.png) 012/100
# process input image(162_1145.png) 013/100
# process input image(168_1278.png) 014/100
# process input image(194_480.png) 015/100
# process input image(195_69.png) 016/100
# process input image(199_445.png) 017/100
# process input image(199_81.png) 018/100
# process input image(204_748.png) 019/100
# process input image(208_441.png) 020/100
# process input image(209_596.png) 021/100
# process input image(20_549.png) 022/100
# process input image(239_533.png) 023/100
# process input image(239_768.png) 024/100
# process input image(248_146.png) 025/100
# process input image(273_186.png) 026/100
# process input image(284_779.png) 027/100
# process input image(285_1113.png) 028/100
# process input image(295_1197.png) 029/100
# process input image(298_1176.png) 030/100
# process input image(299_857.png) 031/100
# process input image(301_266.png) 032/100
# process input image(323_155.png) 033/100
# process input image(329_814.png) 034/100
# process input image(33_1215.png) 035/100
# process input image(35_1277.png) 036/100
# process input image(366_1142.png) 037/100
# process input image(385_723.png) 038/100
# process input image(393_217.png) 039/100
# process input image(395_549.png) 040/100
# process input image(399_643.png) 041/100
# process input image(401_79.png) 042/100
# process input image(405_810.png) 043/100
# process input image(407_326.png) 044/100
# process input image(40_1303.png) 045/100
# process input image(415_230.png) 046/100
# process input image(416_705.png) 047/100
# process input image(418_969.png) 048/100
# process input image(425_414.png) 049/100
# process input image(451_484.png) 050/100
# process input image(452_1238.png) 051/100
# process input image(452_876.png) 052/100
# process input image(455_192.png) 053/100
# process input image(468_410.png) 054/100
# process input image(64_1018.png) 055/100
# process input image(72_490.png) 056/100
# process input image(74_1657.png) 057/100
# process input image(78_885.png) 058/100
# process input image(82_646.png) 059/100
# process input image(88_1008.png) 060/100
# process input image(96_564.png) 061/100
# process input image(9_532.png) 062/100
# Done

# %%
# ! pip install dominate
# Out:
# Collecting dominate
#   Downloading https://files.pythonhosted.org/packages/4f/e6/794a119963b7cfe4bd41177c8f9d4195fe901652f04189fbd2edf513c7b2/dominate-2.5.1-py2.py3-none-any.whl
# Installing collected packages: dominate
# Successfully installed dominate-2.5.1
